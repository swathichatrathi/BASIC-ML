# %% [markdown]
# # EDA ON PENGUINS DATASET

# %% [markdown]
# ## Introduction
# In this notebook, I have done the Exploratory Data Analysis of the penguins dataset and tried to gain useful insights from the data.
# The features present in the dataset are:
# * Bill length
# * Bill Width
# * Flipper length
# * Body mass

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Preliminary Data Processing
# To start off, we read in our dataset and generate a simple preview and statistics of our data.

# %% [markdown]
# ## Loading Data

# %%
df=pd.read_csv("penguins.csv")
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 0         3750.0    male
# 1         3800.0  female
# 2         3250.0  female
# 3            NaN     NaN
# 4         3450.0  female
# ..           ...     ...
# 339       4000.0    male
# 340       3400.0  female
# 341       3775.0    male
# 342       4100.0    male
# 343       3775.0  female
#
# [344 rows x 7 columns]

# %% [markdown]
# The output shows that we have around 344 entries with 7 columns in our dataset.

# %% [markdown]
# ## Understanding the Data

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    male
# 1       3800.0  female
# 2       3250.0  female
# 3          NaN     NaN
# 4       3450.0  female

# %% [markdown]
# The output shows the first 5 rows of our dataset.

# %%
df.tail()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 339       4000.0    male
# 340       3400.0  female
# 341       3775.0    male
# 342       4100.0    male
# 343       3775.0  female

# %% [markdown]
# The output shows the last 5 rows of our dataset.

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# We observe from this above line that our dataset has 344 rows and 7 columns.

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# The output shows the names of the columns in our dataset

# %%
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# 4 of the columns are numeric while the other 3 are categorical which is seen by dtpes function.

# %%
df.describe(include="all")
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# top             NaN  male
# freq            NaN   168
# mean    4201.754386   NaN
# std      801.954536   NaN
# min     2700.000000   NaN
# 25%     3550.000000   NaN
# 50%     4050.000000   NaN
# 75%     4750.000000   NaN
# max     6300.000000   NaN

# %% [markdown]
# This method generates a high-level summary of the attributes over each column of the dataset. More probably, it provides the statistical insights of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# Here is the more information of our dataset chosen.
# We can see that all the columns of our dataset are free from null values.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# From this output, it is clear that we don't have any duplicates in our dataset.

# %%
df["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %% [markdown]
# Here, we observed that our dataset is not balanced to the mark as there are three different species of which Adelie is the most occurring species.

# %%
df.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %% [markdown]
# So, we are having three different islands in our dataset.

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# Here,we get the missing values in each column present in our dataset.

# %%
df.dropna(inplace=True)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    male
# 1       3800.0  female
# 2       3250.0  female
# 4       3450.0  female
# 5       3650.0    male

# %% [markdown]
# From this,we are getting the dataset by removing all the inconsistency present in it.

# %%
df.iloc[:10,:3]
# Out:
#    species     island  bill_length_mm
# 0   Adelie  Torgersen            39.1
# 1   Adelie  Torgersen            39.5
# 2   Adelie  Torgersen            40.3
# 4   Adelie  Torgersen            36.7
# 5   Adelie  Torgersen            39.3
# 6   Adelie  Torgersen            38.9
# 7   Adelie  Torgersen            39.2
# 12  Adelie  Torgersen            41.1
# 13  Adelie  Torgersen            38.6
# 14  Adelie  Torgersen            34.6

# %% [markdown]
# By using positional based indexing function iloc[:10,:3], we got the part of the dataset which is having 10 rows and 3 columns.

# %%
df.loc[:,["bill_length_mm","bill_depth_mm"]]
# Out:
#      bill_length_mm  bill_depth_mm
# 0              39.1           18.7
# 1              39.5           17.4
# 2              40.3           18.0
# 3               NaN            NaN
# 4              36.7           19.3
# ..              ...            ...
# 339            55.8           19.8
# 340            43.5           18.1
# 341            49.6           18.2
# 342            50.8           19.0
# 343            50.2           18.7
#
# [344 rows x 2 columns]

# %% [markdown]
# By using label based indexing function loc[:,["bill_length_mm","bill_depth_mm"]], we got the dataset consisting of Bill length and Bill depth column.

# %%
df.groupby("sex")["body_mass_g"].agg("mean")
# Out:
# sex
# female    3862.272727
# male      4545.684524
# Name: body_mass_g, dtype: float64

# %% [markdown]
# Using groupby() function ,we've grouped the mean bodymass of all the male and female penguins individually.

# %% [markdown]
# # Visualization:

# %% [markdown]
# # COUNT PLOT

# %%
plt.title('No. of Species')
plot=sns.countplot(x="species",data=df)

# %% [markdown]
# From this visualization,we can observe that our dataset is not balanced as we don't have equal number of count of the species.
# We can also observe that we have more number of Adelie species of the penguins maintaining a huge differnce with the count of the Chinstrap.

# %% [markdown]
# # SCATTER PLOT

# %%
plot=sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',hue="species",data=df)

# %% [markdown]
# From the above visualization, we can tell that the Adelie species has smaller bill length but higher depth.
# While we see Chinstrap species lies in almost middle for length as well as depth.
# And the Gentoo species has larger bill lengths and smaller bill depths.

# %% [markdown]
# # STRIP PLOT

# %%
fig, axs = plt.subplots(figsize = (6,6))
plot=sns.stripplot(x="species",y="bill_length_mm",hue="sex",data=df);

# %% [markdown]
# From the above visualization,we observed that the male penguins has higher bill length when compared to female penguins in all the three species of our dataset.

# %% [markdown]
# # BOX PLOT

# %%
fig, axs = plt.subplots(figsize = (8,6))
plot=sns.boxplot(x="species",y="body_mass_g",data=df)

# %% [markdown]
# Here,we can observe that both Adelie and Chinstrap species have almost equal range of body masses.So,we can only differentiate the Gentoo species from the above box plot.We can also observe the outliers present among the Chinstrap species.

# %% [markdown]
# ## Correlation Between Variables

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# Further, we can visualise this correlation using a heatmap.

# %% [markdown]
# # Heat map

# %%
fig = plt.figure(figsize = (15,9))
sns.heatmap(df.corr(), cmap='Reds', annot = True);

# %% [markdown]
# From the above heatmap, we see that flipper_length and body mass have a high correlation,
# body mass and bill length have good correlation as well as flipper_length and bill_length have good correlations.

# %% [markdown]
# # HIST PLOT

# %%
df.hist(edgecolor='black',bins = 25, figsize= (12,6))
plt.show()

# %% [markdown]
# Here,we can visualize the distribution of length,depth and mass of our dataset.

# %% [markdown]
# # PAIR PLOT

# %%
sns.pairplot(data = df,hue="species", height=3)

# %% [markdown]
# pairplot is showing the bivariate relation between each pair of features.
# From the pairplot, we'll see that the Gento species is separataed from the other two across all feature combinations

# %% [markdown]
# # JOINT PLOT

# %%
sns.jointplot(x="bill_length_mm", y="bill_depth_mm", data=df,height=5)
plt.show()

# %% [markdown]
# We can also use the seaborn library to make a similar plot.
# A seaborn jointplot shows bivariate scatterplots and univariate histograms in the same figure.

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.violinplot(x="species", y="body_mass_g", data=df, size=6)
plt.show()

# %% [markdown]
# Here,we can observe that both Adelie and Chinstrap species have almost equal range of body masses.
# So,we can only differentiate the Gentoo species from the above violin plot.
# We can also observe the outliers present among the Chinstrap species

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# * The dataset is not balanced i.e. equal records are not present for all three species.
# * We have four numerical columns while three categorical columns.
# * A strong correlation is present between flipper length and body mass.
# * The Gentoo species is the most easily distinguishable because of its large body masses.
# * The Adelie and Chinstrap species are usually mixed and are sometimes hard to separate.
